# %%
from IPython.display import Image

# %%
Image(filename="E:/Big Data/Seguro Vehicular/Proyecto/Imagenes/Diapositiva1.jpg")

# %%
Image(filename="E:/Big Data/Seguro Vehicular/Proyecto/Imagenes/Diapositiva2.jpg")

# %%
Image(filename="E:/Big Data/Seguro Vehicular/Proyecto/Imagenes/Diapositiva3.jpg")

# %%
Image(filename="E:/Big Data/Seguro Vehicular/Proyecto/Imagenes/Diapositiva4.jpg")

# %%
Image(filename="E:/Big Data/Seguro Vehicular/Proyecto/Imagenes/Diapositiva5.jpg")

# %%
Image(filename="E:/Big Data/Seguro Vehicular/Proyecto/Imagenes/Diapositiva6.jpg")

# %%
Image(filename="E:/Big Data/Seguro Vehicular/Proyecto/Imagenes/Diapositiva7.jpg")

# %%
Image(filename="E:/Big Data/Seguro Vehicular/Proyecto/Imagenes/Diapositiva8.jpg")

# %%
Image(filename="E:/Big Data/Seguro Vehicular/Proyecto/Imagenes/Diapositiva8.jpg")

# %%
Image(filename="E:/Big Data/Seguro Vehicular/Proyecto/Imagenes/Diapositiva10.jpg")

# %%
Image(filename="E:/Big Data/Seguro Vehicular/Proyecto/Imagenes/Diapositiva11.jpg")

# %%
Image(filename="E:/Big Data/Seguro Vehicular/Proyecto/Imagenes/Diapositiva12.jpg")

# %%
#SCRIPT INGESTA

hdfs dfs -mkdir /labotica/data/clientes
hdfs dfs -mkdir /labotica/data/cobranzas
hdfs dfs -mkdir /labotica/data/vehiculos

hdfs dfs -put BD_CLIENTES.csv /labotica/data/clientes
hdfs dfs -put BD_COBRANZAS.csv /labotica/data/cobranzas
hdfs dfs -put BD_INTERAC_VEH.csv /labotica/data/vehiculos

#hive

hive
create database labotica;

#Salir con Control+d

beeline -u jdbc:hive2://localhost:10000/labotica

create table labotica.clientes(
id string,
sexo string,
fecha string,
ubicacion string,
departamento string,
ubigeo string,
cuc string
)
COMMENT 'Tabla clientes del grupo labotica'
ROW FORMAT DELIMITED
FIELDS TERMINATED BY ','
LINES TERMINATED BY '\n'
STORED AS TEXTFILE
LOCATION '/labotica/data/clientes'
tblproperties("skip.header.line.count" = "1")
;

create table labotica.interac_vehiculo(
id string,
descripcion string,
periodo string,
cuc string
)
COMMENT 'Tabla interaccion de vehiculos del grupo labotica'
ROW FORMAT DELIMITED
FIELDS TERMINATED BY ','
LINES TERMINATED BY '\n'
STORED AS TEXTFILE
LOCATION '/labotica/data/vehiculos'
tblproperties("skip.header.line.count" = "1")

# %%
Image(filename="E:/Big Data/Seguro Vehicular/Proyecto/Imagenes/Diapositiva13.jpg")

# %%
Image(filename="E:/Big Data/Seguro Vehicular/Proyecto/Imagenes/Diapositiva14.jpg")

# %%
Image(filename="E:/Big Data/Seguro Vehicular/Proyecto/Imagenes/Diapositiva15.jpg")

# %%
Image(filename="E:/Big Data/Seguro Vehicular/Proyecto/Imagenes/Diapositiva16.jpg")

# %%
Image(filename="E:/Big Data/Seguro Vehicular/Proyecto/Imagenes/Diapositiva17.jpg")

# %%
Image(filename="E:/Big Data/Seguro Vehicular/Proyecto/Imagenes/Diapositiva18.jpg")

# %%
Image(filename="E:/Big Data/Seguro Vehicular/Proyecto/Imagenes/Diapositiva19.jpg")

# %%
Image(filename="E:/Big Data/Seguro Vehicular/Proyecto/Imagenes/Diapositiva20.jpg")

# %%
Image(filename="E:/Big Data/Seguro Vehicular/Proyecto/Imagenes/Diapositiva21.jpg")

# %%
Image(filename="E:/Big Data/Seguro Vehicular/Proyecto/Imagenes/Diapositiva22.jpg")

# %%
Image(filename="E:/Big Data/Seguro Vehicular/Proyecto/Imagenes/Diapositiva23.jpg")

# %%
Image(filename="E:/Big Data/Seguro Vehicular/Proyecto/Imagenes/Diapositiva24.jpg")

# %%
Image(filename="E:/Big Data/Seguro Vehicular/Proyecto/Imagenes/Diapositiva25.jpg")

# %%
Image(filename="E:/Big Data/Seguro Vehicular/Proyecto/Imagenes/Diapositiva26.jpg")
